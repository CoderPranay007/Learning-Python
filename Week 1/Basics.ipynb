# %%
print("Hello World")
# Out:
# Hello World

# %%
num=float(input("Enter a number:"))
print(num)
# Out:
# Enter a number: 6
# 6.0

# %%
Text=input("Enter a text:")
print(Text)

#It is considered and stored as a string by default
# Out:
# Enter a text: Hi I am Pranay
# Hi I am Pranay

# %%
x=int(input("Enter an integer"))
print(x+1)
# Out:
# Enter an integer 9
# 10

# %%
name = "Pranay"
age = 19

print(name, age)

# Variable declaration
# Out:
# Pranay 19

# %%
a = 19
b = 9.5
c = "Pranay"
d = True

print(type(a), type(b), type(c), type(d))

# Datatypes
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
ch = 'x'

print((type(ch)))
# Out:
# <class 'str'>
