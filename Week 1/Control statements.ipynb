# %%
a=float(input("Enter your age:"))

if a<=20:
    print("You are eligible")
# Out:
# Enter your age: 19
# You are eligible

# %%
a=float(input("Enter your age:"))

if a<=20:
    print("You are eligible")
else: print("You are not eligible")
# Out:
# Enter your age: 19
# You are eligible

# %%
a=input("Enter code name:")

if a.lower()=='ak47':
        print("You are welcome")
else: print("Wrong code")
# Out:
# Enter code name: Ak47
# You are welcome

# %%
a=int(input("Enter your age:"))

if a<=17:
    print("You are not eligible i.e under aged")
elif a>17 and a<=25:
    b=int(input("Provide contact number:"))
    print("Thankyou")
else:print("You are not eligible i.e over aged")
# Out:
# Enter your age: 19
# Provide contact number: 1234567890
# Thankyou
