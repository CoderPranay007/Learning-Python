# %%
a=4
b=8
sum= a+b
print(sum)
print(b%a) #remainder
print(a**b) #a^b i.e power
# Out:
# 12
# 0
# 65536

# %%
a=float(input("a:"))
b=float(input("b:"))

final=a*b
print(final)
# Out:
# a: 8
# b: 9
# 72.0

# %%
p=float(input("Enter Principal amount:"))
r=float(input("Enter Rate of Interest:"))
t=float(input("Enter Time Period:"))

Total= p * ( 1 + r/100)**t

print(Total)
# Out:
# Enter Principal amount: 10000
# Enter Rate of Interest: 7.4
# Enter Time Period: 10
# 20419.392332799103

# %%
num1= 34
num2= 46

print(num1>num2)
# Out:
# False

# %%
num1= 34
num2= 46

print(num1!=num2)
# Out:
# True

# %%
num = 3.145
print(round(num, 2))
# Out:
# 3.15
